# %% [markdown]
# # Regression with a Flood Prediction Dataset

# %% [markdown]
# ## corelacao de pearson

# %%
import pandas as pd 
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# salvando validacao treino e teste

# %%
df = pd.read_csv("train.csv")
df_test = pd.read_csv("test.csv")

# %% [markdown]
# # leitura dos dados

# %%
nulos = df.isnull().sum()
print(nulos)
dublicados = df.duplicated().sum()
print(dublicados)
df.drop('id', inplace=True, axis= 1)
# Out:
# id                                 0
# MonsoonIntensity                   0
# TopographyDrainage                 0
# RiverManagement                    0
# Deforestation                      0
# Urbanization                       0
# ClimateChange                      0
# DamsQuality                        0
# Siltation                          0
# AgriculturalPractices              0
# Encroachments                      0
# IneffectiveDisasterPreparedness    0
# DrainageSystems                    0
# CoastalVulnerability               0
# Landslides                         0
# Watersheds                         0
# DeterioratingInfrastructure        0
# PopulationScore                    0
# WetlandLoss                        0
# InadequatePlanning                 0
# PoliticalFactors                   0
# FloodProbability                   0
# dtype: int64
# 0

# %% [markdown]
# # plot da matriz de correlação

# %% [markdown]
# # análise de correlação

# %%
correlation = df.corr()
sns.heatmap(correlation, annot = True, fmt=".1f", linewidths=.6)
# Out:
# <Axes: >

# %% [markdown]
# ## Divida os dados de treinamento em entrada X e saída Y

# %%
X = df.drop(['FloodProbability'], axis=1).values.astype(float)

#Quase sempre é uma boa ideia realizar algum escalonamento dos valores de entrada ao usar modelos de redes neurais (jb).

scale = StandardScaler()
X = scale.fit_transform(X)

# Y is just the 'FloodProbability' column
Y = df['FloodProbability'].values
